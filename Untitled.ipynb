# %% [markdown]
# # Matplotlib

# %% [markdown]
# 1. plt
# 2. ax
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
x = np.linspace(0,10*np.pi,200)
ycos = np.cos(x)
yexp = np.exp(-0.1*x)

# %%
plt.plot(x,ycos)

# %%
plt.plot(x,ycos,'bo')

# %%
plt.plot(x,yexp,'k-',x,ycos*yexp,'bo')

# %%
plt.plot(x, yexp, color='green', linestyle='-', linewidth=1)
plt.plot(x, yexp*ycos, color='blue', linestyle='-', linewidth=1)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi])
plt.yticks([-1, -0.5, 0, 0.5, 1])

plt.xlabel('x')
plt.ylabel('y')
plt.title('Decaying sinusoid')

plt.show();

# %%
plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi])
plt.yticks([-1, -0.5, 0, 0.5, 1])

plt.xlabel('x')
plt.ylabel('y')
plt.title('Decaying sinusoid')

plt.show();

# %%
plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)

plt.show();

# %%
plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)

plt.box(on=None)
plt.axhline(y=0, color='black')
plt.axvline(x=0, color='black')

plt.annotate('$e^{-x}\cos(x)$', color='blue',
             xy=(3*np.pi, np.cos(3*np.pi)*np.exp(-0.3*np.pi)), xycoords='data',
             xytext=(30, -30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=-.3"))
plt.annotate('$e^{-x}$', color='green',
             xy=(3*np.pi, np.exp(-0.3*np.pi)), xycoords='data',
             xytext=(+25, +25), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.5"))

plt.show();

# %%
fig,ax = plt.subplots(3,1)

plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)

plt.show();

# %%
fig,ax = plt.subplots(3,1)

plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)

plt.tight_layout()
plt.show();

# %%
fig,ax = plt.subplots(3,1,figsize=(8,5))

plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)

plt.tight_layout()
plt.show();

# %%
#fig = plt.figure(figsize=(8,5))
#,ax = plt.subplots(3,1,figsize=(8,5))

plt.axes([0,0,1,1])
plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(-1,1)

plt.xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi],
           ['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'],
           fontsize=12)
plt.yticks([-1, -0.5, 0, 0.5, 1],fontsize=12)

plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.title('Decaying sinusoid',fontsize=16)


plt.axes([0.7,0.7,0.2,0.2])
plt.plot(x, yexp, color='green', linestyle=':', linewidth=3)
#plt.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

plt.xlim(0,10*np.pi)
plt.ylim(0,1)

plt.xticks([0, 10*np.pi],
           ['$0$', '$10\pi$'],
           fontsize=10)
plt.yticks([0, 1],fontsize=10)

plt.xlabel('x',fontsize=12)
plt.ylabel('y',fontsize=12)
plt.title('Decaying exponential',fontsize=12)

#plt.tight_layout()
plt.show();

# %%
fig,ax = plt.subplots(1,1,figsize=(8,5))

ax.plot(x, yexp, color='green', linestyle=':', linewidth=3)
ax.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

ax.set_xlim([0,10*np.pi])
ax.set_ylim([-1,1])

ax.set_xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi])
ax.set_xticklabels(['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'], fontsize=12)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticklabels([-1.0, -0.5, 0.0, 0.5, 1.0],fontsize=12)

ax.set_xlabel('x',fontsize=14)
ax.set_ylabel('y',fontsize=14)
ax.set_title('Decaying sinusoid',fontsize=16)

plt.show();

# %%
fig,ax = plt.subplots(1,1,figsize=(8,5))

ax.plot(x, yexp, color='green', linestyle=':', linewidth=3)
ax.plot(x, yexp*ycos, color='blue', linestyle='-.', linewidth=2)

ax.set(xlim=[0,10*np.pi], ylim=[-1,1])

ax.set_xticks([0, 2*np.pi, 4*np.pi, 6*np.pi, 8*np.pi, 10*np.pi])
ax.set_xticklabels(['$0$', '$2\pi$', '$4\pi$', '$6\pi$', '$8\pi$', '$10\pi$'], fontsize=12)
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticklabels([-1.0, -0.5, 0.0, 0.5, 1.0],fontsize=12)

ax.set_xlabel('x',fontsize=14)
ax.set_ylabel('y',fontsize=14)
ax.set_title('Decaying sinusoid',fontsize=16)

plt.show();

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.gca()

ax.plot(x,yexp,'k-',x,ycos*yexp,'bo');

# %%
plt.figure(figsize=(8,5))
ax = plt.subplot(111)

ax.plot(x,yexp,'k-',x,ycos*yexp,'bo');

# %%
plt.figure(figsize=(8,5))

ax = plt.subplot(211)
ax.plot(x,yexp,'k-');

ax = plt.subplot(212)
ax.plot(x,ycos*yexp,'bo');

# %%
#plt.figure(figsize=(8,5))
fig,ax = plt.subplots(2,1,figsize=(8,5))

# ax = plt.subplot(211)
# ax.plot(x,yexp,'k-');
ax[0].plot(x,yexp,'k-');

# ax = plt.subplot(212)
# ax.plot(x,ycos*yexp,'bo');
ax[1].plot(x,ycos*yexp,'bo');

# %%
fig,ax = plt.subplots(figsize=(8,5))

ax.plot(x,yexp,'k-',x,ycos*yexp,'bo');

# %%
fig,ax = plt.subplots(1,1,figsize=(8,5))

ax.plot(x,yexp,'k-',x,ycos*yexp,'bo');

# %%
fig,ax = plt.subplots(1,1,figsize=(8,5))

ax.plot(x,yexp,'k-',x,ycos*yexp,'bo');

# %% [markdown]
# # Types of plots
#
# * line (or marker)
# * scatter
# * bar
# * histogram
# * box plot
# * pie chart
#
# use anscombe's data

# %%
import seaborn as sns
sns.set(style="ticks")
df = sns.load_dataset("anscombe")

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
fig,ax = plt.subplots(2,2,figsize=(8,6))
ax = ax.ravel()

count = 0
for i in ['I','II','III','IV']:
    ax[count].plot(df.loc[df.dataset==i,'x'], df.loc[df.dataset==i,'y'], 'ko')
    ax[count].set(xlim=[0,20],ylim=[0,14])
    count+=1
    
plt.tight_layout()
plt.show();

# %%
#fig,ax = plt.subplots(2,2,figsize=(8,6))
# ax = ax.ravel()

df2 = df.groupby('dataset')
for k,i in df.groupby('dataset'):
    i.plot.scatter(x='x', y='y', xlabel="new x", ylabel="new y", c='b');
#     count+=1
    
# plt.tight_layout()
# plt.show();

# %%
fig,ax = plt.subplots(2,2,figsize=(8,6))
ax = ax.ravel()

df2 = df.groupby('dataset')
count=0
for k,i in df.groupby('dataset'):
    #print(i)
    i.plot.scatter(ax=ax[count], x='x', y='y', xlabel="new x", ylabel="new y", c='b');
    count+=1
    
plt.tight_layout()
# plt.show();

# %%
sns.FacetGrid(data=df, x="x", y="y",row='dataset',hue='dataset');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-7ee2aae859c2> in <module>
# ----> 1 sns.FacetGrid(data=df, x="x", y="y",row='dataset',hue='dataset');
#
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: __init__() got an unexpected keyword argument 'x'

# %%
sns.lmplot(data=df, x="x", y="y",
           hue="dataset");

# %%
sns.lmplot(data=df, x="x", y="y",
           col="dataset");

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

X2 = np.linspace(0.0, 2*np.pi, 100)
Y12 = 3+np.cos(X2)
Y22 = 1+np.cos(1+X2/0.75)/2
Y32 = np.random.uniform(Y12, Y22, len(X2))

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)

ax.plot(X,Y1,'g-',lw=2)
ax.plot(X,Y2,lw=2)
ax.plot(X,Y3,'ko')
ax.plot(X2,Y12,'g--',X2,Y22,'r--',X2,Y32,'bo')

plt.show()

# %%
fig = plt.figure(figsize=(8*6.28/4, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)

ax.plot(X,Y1,'k-',lw=3)
ax.plot(X,Y2,'k-',lw=3)
ax.plot(X,Y3,'ko')
ax.plot(X2,Y12,'g--',X2,Y22,'r--',X2,Y32,'bo')

ax.plot([0.5, 0.5], [3+np.cos(0.5), 1+np.cos(1+0.5/0.75)/2], 'k-', lw=3)
ax.plot([3.5, 3.5], [3+np.cos(3.5), 1+np.cos(1+3.5/0.75)/2], 'k-', lw=3)

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(0, 4)

plt.show()

# %%
fig = plt.figure(figsize=(8*6.28/4, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)

ax.plot(X,Y1,'k-',lw=3)
ax.plot(X,Y2,'k-',lw=3)
ax.plot(X,Y3,'ko')
ax.plot(X2,Y12,'g--',label='green')
ax.plot(X2,Y22,'r--',label='red')
ax.plot(X2,Y32,'bo')

ax.plot([0.5, 0.5], [3+np.cos(0.5), 1+np.cos(1+0.5/0.75)/2], 'k-', lw=3)
ax.plot([3.5, 3.5], [3+np.cos(3.5), 1+np.cos(1+3.5/0.75)/2], 'k-', lw=3)

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(0, 4)

ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(8*6.28/4, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)

ax.plot(X,Y1,'k-',lw=3)
ax.plot(X,Y2,'k-',lw=3)
ax.plot(X,Y3,'ko')
ax.plot(X2,Y12,'g--',label='green')
ax.plot(X2,Y22,'r--',label='red')
ax.plot(X2,Y32,'bo')

ax.plot([0.5, 0.5], [3+np.cos(0.5), 1+np.cos(1+0.5/0.75)/2], 'k-', lw=3)
ax.plot([3.5, 3.5], [3+np.cos(3.5), 1+np.cos(1+3.5/0.75)/2], 'k-', lw=3)

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(0, 4)

ax.legend(fontsize=14, loc='lower center')
ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return f"{x:.2f}"

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
# FuncFormatter is created and used automatically
ax.xaxis.set_minor_formatter(minor_tick)

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')


# Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

# Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

# Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

# Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

# X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

# Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

# Title
circle(1.60, 4.13)
text(1.60, 3.93, "Title")

# Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

# Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

# Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

# Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

# Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

# Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

# Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xytext=(3.3, 0.5),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xytext=(3.45, 0.45),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with https://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()
